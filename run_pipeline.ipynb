# %%
import papermill as pm
import numpy as np
import pandas as pd
from os import mkdir, listdir
from os.path import exists, isfile, join
import json

# %%
def load_config(config_path = 'config.json'):
    file = open(config_path,'r')
    return json.load(file)

# %%
config = load_config('config.json')

# %%
config
# Out:
# {'img_height': 128,
#  'img_width': 192,
#  'epochs': 3,
#  'batch_size': 128,
#  'remove_background': False,
#  'need_training': True,
#  'prepare_datasets': True,
#  'datasets_paths': [['/usr/data/shared_directory/team_1/data/plant_pathology_2020',
#    'data_transforms/plant_pathology_2020_transform.ipynb']],
#  'do_augmentation': True,
#  'model_name': 'datagen-test',
#  'model_json_path': None,
#  'model_weights_path': None}

# %%
output_notebooks_dir = 'output_notebooks'

if not exists(output_notebooks_dir):
    mkdir(output_notebooks_dir) 
    
def craft_output_notebook_name(notebook_name):
    name = notebook_name.split('/')[-1]
    return join(output_notebooks_dir,name)

# %%
# запускаем трансформ датасетов

if config['prepare_datasets']:
    
    datasets_paths = config['datasets_paths']
    
    for (dataset_path,notebook_path) in datasets_paths:
        pm.execute_notebook(
            input_path = notebook_path,
            output_path = craft_output_notebook_name(notebook_path),
            parameters=dict(dataset_path = dataset_path,
                           output_path = 'data_transforms'),
            nest_asyncio=True
        )
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Executing', max=7.0, style=ProgressStyle(description_widt…

# %%
# запускаем file rearrange

if config['prepare_datasets']:
    
    if not exists('data'):
        mkdir('data')
        
    pm.execute_notebook(
        input_path = 'file_rearrange.ipynb',
        output_path = craft_output_notebook_name('file_rearrange.ipynb'),
        parameters = dict(csv_folder = 'data_transforms',
                         output_path_pathologies = 'data',
                         output_path_plants = 'data'),
        nest_asyncio=True
    )
    
#train_pathology.csv
#test_pathology.csv
#train_plants.csv
#test_plants.csv
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Executing', max=15.0, style=ProgressStyle(description_wid…

# %%
# запускаем copy_resize
if config['prepare_datasets']:
    
    pm.execute_notebook(
        input_path = 'copy_resize.ipynb',
        output_path = craft_output_notebook_name('copy_resize.ipynb'),
        parameters = dict(root = 'data'),
        nest_asyncio=True
    )
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Executing', max=12.0, style=ProgressStyle(description_wid…

# %%
# запусксем тренировку модели

pm.execute_notebook(
    input_path = 'train_model.ipynb',
    output_path = craft_output_notebook_name('train_model.ipynb'),
    parameters = dict(
        train_pathology_path = 'data/train_pathology.csv',
        test_pathology_path = 'data/test_pathology.csv',
        train_plants_path = 'data/train_plants.csv',
        test_plants_path = 'data/test_plants.csv'
    ),
    nest_asyncio=True
)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Executing', max=23.0, style=ProgressStyle(description_wid…
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:55:08.339035',
#      'end_time': '2020-06-17T13:55:08.356063',
#      'duration': 0.017028,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:55:08.353925Z',
#      'iopub.execute_input': '2020-06-17T13:55:08.354191Z',
#      'iopub.status.idle': '2020-06-17T13:55:08.355594Z',
#      'shell.execute_reply': '2020-06-17T13:55:08.355966Z'}},
#    'outputs': [],
#    'source': "train_pathology_path = 'data/train_pathology.csv'\ntest_pathology_path = 'data/test_pathology.csv'\ntrain_plants_path = 'data/train_plants.csv'\ntest_plants_path = 'data/test_plants.csv'"},
#   {'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:55:08.366620',
#      'end_time': '2020-06-17T13:55:08.377651',
#      'duration': 0.011031,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:55:08.375876Z',
#      'iopub.execute_input': '2020-06-17T13:55:08.376142Z',
#      'shell.execute_reply': '2020-06-17T13:55:08.377346Z',
#      'iopub.status.idle': '2020-06-17T13:55:08.377611Z'}},
#    'execution_count': 2,
#    'source': '# Parameters\ntrain_pathology_path = "data/train_pathology.csv"\ntest_pathology_path = "data/test_pathology.csv"\ntrain_plants_path = "data/train_plants.csv"\ntest_plants_path = "data/test_plants.csv"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:55:08.384684',
#      'end_time': '2020-06-17T13:55:08.396614',
#      'duration': 0.01193,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:55:08.394512Z',
#      'iopub.execute_input': '2020-06-17T13:55:08.394765Z',
#      'iopub.status.idle': '2020-06-17T13:55:08.396320Z',
#      'shell.execute_reply': '2020-06-17T13:55:08.396565Z'}},
#    'outputs': [],
#    'source': "import json\ndef load_config(config_path = 'config.json'):\n    file = open(config_path,'r')\n    return json.load(file)\n\nconfig = load_config()"},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:55:08.403877',
#      'end_time': '2020-06-17T13:55:09.673711',
#      'duration': 1.269834,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:55:08.418745Z',
#      'iopub.execute_input': '2020-06-17T13:55:08.419013Z',
#      'iopub.status.idle': '2020-06-17T13:55:09.673191Z',
#      'shell.execute_reply': '2020-06-17T13:55:09.673606Z'}},
#    'outputs': [],
#    'source': 'import os\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport pandas as pd\nimport cv2\nimport tensorflow as tf, tensorflow.keras.backend as K\nimport matplotlib.pyplot as plt\n\nfrom os import mkdir, listdir\nfrom os.path import exists, isfile, join\nimport json\n\nfrom tensorflow.keras.layers import Dense,BatchNormalization,Dropout,Input,Flatten,Activation,Conv2D\nfrom tensorflow.keras.models import Model\nfrom tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping\nfrom tensorflow.keras.optimizers import Adam\nfrom sklearn.model_selection import StratifiedShuffleSplit\nfrom sklearn.utils.class_weight import compute_class_weight'},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:55:09.688355',
#      'end_time': '2020-06-17T13:55:18.840463',
#      'duration': 9.152108,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:55:18.837517Z',
#      'iopub.execute_input': '2020-06-17T13:55:18.838049Z',
#      'shell.execute_reply': '2020-06-17T13:55:18.839838Z',
#      'iopub.status.idle': '2020-06-17T13:55:18.840376Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "[PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]"},
#      'execution_count': 5}],
#    'source': "tf.config.experimental.list_physical_devices('GPU')"},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:55:18.852292',
#      'end_time': '2020-06-17T13:55:18.866087',
#      'duration': 0.013795,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:55:18.864399Z',
#      'iopub.execute_input': '2020-06-17T13:55:18.864672Z',
#      'shell.execute_reply': '2020-06-17T13:55:18.865768Z',
#      'iopub.status.idle': '2020-06-17T13:55:18.866042Z'}},
#    'outputs': [],
#    'source': "import tensorflow as tf\ngpus = tf.config.experimental.list_physical_devices('GPU')\ntf.config.experimental.set_memory_growth(gpus[0], True)"},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:55:18.876533',
#      'end_time': '2020-06-17T13:55:18.889842',
#      'duration': 0.013309,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:55:18.888335Z',
#      'iopub.execute_input': '2020-06-17T13:55:18.888603Z',
#      'iopub.status.idle': '2020-06-17T13:55:18.889532Z',
#      'shell.execute_reply': '2020-06-17T13:55:18.889789Z'}},
#    'outputs': [],
#    'source': 'def train_val_split(x_train,y_train, test_size = 0.2):\n    x_train = np.array(x_train)\n    y_train = np.array(y_train)\n    sss = StratifiedShuffleSplit(n_splits=1, test_size = test_size, random_state=0)\n    for train_index, test_index in sss.split(x_train, y_train):\n        x_train, x_test = x_train[train_index], x_train[test_index]\n        y_train, y_test = y_train[train_index], y_train[test_index]\n    return x_train, y_train, x_test, y_test'},
#   {'cell_type': 'code',
#    'execution_count': 8,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:55:18.898594',
#      'end_time': '2020-06-17T13:55:18.912778',
#      'duration': 0.014184,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:55:18.911226Z',
#      'iopub.execute_input': '2020-06-17T13:55:18.911543Z',
#      'iopub.status.idle': '2020-06-17T13:55:18.912403Z',
#      'shell.execute_reply': '2020-06-17T13:55:18.912699Z'}},
#    'outputs': [],
#    'source': "def get_train_data(path):\n    \n    df = pd.read_csv(path)\n    \n    paths = df.pop('path')\n    \n    paths = [str(elem) for elem in paths]\n    \n    y = df.to_numpy().astype('float32')\n \n    return np.array(paths),y"},
#   {'cell_type': 'code',
#    'execution_count': 9,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:55:18.924365',
#      'end_time': '2020-06-17T13:55:18.943494',
#      'duration': 0.019129,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:55:18.934269Z',
#      'iopub.execute_input': '2020-06-17T13:55:18.934529Z',
#      'iopub.status.idle': '2020-06-17T13:55:18.943176Z',
#      'shell.execute_reply': '2020-06-17T13:55:18.943433Z'}},
#    'outputs': [],
#    'source': 'x_train_pathology,y_train_pathology = get_train_data(train_pathology_path)\nx_train_plants,y_train_plants = get_train_data(train_plants_path)'},
#   {'cell_type': 'code',
#    'execution_count': 10,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:55:18.956256',
#      'end_time': '2020-06-17T13:55:18.984824',
#      'duration': 0.028568,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:55:18.968819Z',
#      'iopub.execute_input': '2020-06-17T13:55:18.969333Z',
#      'iopub.status.idle': '2020-06-17T13:55:18.984235Z',
#      'shell.execute_reply': '2020-06-17T13:55:18.984720Z'}},
#    'outputs': [],
#    'source': 'x_train_pathology,y_train_pathology,x_val_pathology,y_val_pathology = train_val_split(x_train_pathology,y_train_pathology)\n\nx_train_plants,y_train_plants,x_val_plants,y_val_plants = train_val_split(x_train_plants,y_train_plants)'},
#   {'cell_type': 'code',
#    'execution_count': 11,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:55:18.999589',
#      'end_time': '2020-06-17T13:55:19.013074',
#      'duration': 0.013485,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:55:19.011313Z',
#      'iopub.execute_input': '2020-06-17T13:55:19.011572Z',
#      'iopub.status.idle': '2020-06-17T13:55:19.012812Z',
#      'shell.execute_reply': '2020-06-17T13:55:19.013020Z'}},
#    'outputs': [],
#    'source': 'from tensorflow.keras.models import model_from_json\n\ndef load_model(model_path,weights_path):\n    \n    json_file = open(model_path, \'r\')\n    loaded_model_json = json_file.read()\n    json_file.close()\n    loaded_model = model_from_json(loaded_model_json)\n    loaded_model.load_weights(weights_path)\n\n    print("model loaded successfully")\n    return loaded_model\n'},
#   {'cell_type': 'code',
#    'execution_count': 12,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:55:19.020937',
#      'end_time': '2020-06-17T13:55:19.034118',
#      'duration': 0.013181,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:55:19.032431Z',
#      'iopub.execute_input': '2020-06-17T13:55:19.032687Z',
#      'shell.execute_reply': '2020-06-17T13:55:19.033819Z',
#      'iopub.status.idle': '2020-06-17T13:55:19.034079Z'}},
#    'outputs': [],
#    'source': "img_height = config['img_height']\nimg_width = config['img_width']\nepochs = config['epochs']\nbatch_size = config['batch_size']\n\nneed_training = config['need_training']\n\nmodel_name = config['model_name']\nmodel_json_path = config['model_json_path']\nmodel_weights_path = config['model_weights_path']\n\nnb_classes = y_train_pathology.shape[1]"},
#   {'cell_type': 'code',
#    'execution_count': 13,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:55:19.042084',
#      'end_time': '2020-06-17T13:55:19.126388',
#      'duration': 0.084304,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:55:19.055540Z',
#      'iopub.execute_input': '2020-06-17T13:55:19.056080Z',
#      'shell.execute_reply': '2020-06-17T13:55:19.126022Z',
#      'iopub.status.idle': '2020-06-17T13:55:19.126336Z'}},
#    'outputs': [],
#    'source': "import efficientnet.tfkeras as efn\nfrom tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input, decode_predictions\nfrom tensorflow.keras.layers import GlobalAveragePooling2D\n\ndef get_model():\n    '''\n    inp = Input(shape=(img_height,img_width,3))\n    x = Flatten()(inp)\n    x = Dense(nb_classes,activation='softmax')(x)\n    return Model(inp,x)\n    \n    '''\n    base_model = efn.EfficientNetB0(weights='imagenet',\n                              include_top=False,\n                              input_shape=(img_height,img_width, 3),\n                              pooling='avg')\n        \n    x = base_model.output\n    predictions = Dense(nb_classes,activation='softmax')(x)\n    \n    return Model(base_model.input,predictions)\n    \n    '''\n    base_model = MobileNetV2(include_top=False, weights='imagenet', input_shape=(img_height, img_width, 3))\n \n    x = base_model.output\n    x = GlobalAveragePooling2D()(x)\n  \n    predictions = Dense(nb_classes, activation='softmax')(x)\n \n    return Model(inputs=base_model.input, outputs=predictions)\n    '''"},
#   {'cell_type': 'code',
#    'execution_count': 14,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:55:19.137571',
#      'end_time': '2020-06-17T13:55:23.023832',
#      'duration': 3.886261,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:55:19.147795Z',
#      'iopub.execute_input': '2020-06-17T13:55:19.148071Z',
#      'shell.execute_reply': '2020-06-17T13:55:23.023180Z',
#      'iopub.status.idle': '2020-06-17T13:55:23.023742Z'}},
#    'outputs': [],
#    'source': 'model = None\nif (model_json_path is None):\n    model = get_model()\nelse:\n    model = load_model(model_json_path,model_weights_path)'},
#   {'cell_type': 'code',
#    'execution_count': 15,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:55:23.035880',
#      'end_time': '2020-06-17T13:55:23.097653',
#      'duration': 0.061773,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:55:23.047574Z',
#      'iopub.execute_input': '2020-06-17T13:55:23.047837Z',
#      'iopub.status.idle': '2020-06-17T13:55:23.096987Z',
#      'shell.execute_reply': '2020-06-17T13:55:23.097542Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Model: "model"\n__________________________________________________________________________________________________\nLayer (type)                    Output Shape         Param #     Connected to                     \n==================================================================================================\ninput_1 (InputLayer)            [(None, 128, 192, 3) 0                                            \n__________________________________________________________________________________________________\nstem_conv (Conv2D)              (None, 64, 96, 32)   864         input_1[0][0]                    \n__________________________________________________________________________________________________\nstem_bn (BatchNormalization)    (None, 64, 96, 32)   128         stem_conv[0][0]                  \n__________________________________________________________________________________________________\nstem_activation (Activation)    (None, 64, 96, 32)   0           stem_bn[0][0]                    \n__________________________________________________________________________________________________\nblock1a_dwconv (DepthwiseConv2D (None, 64, 96, 32)   288         stem_activation[0][0]            \n__________________________________________________________________________________________________\nblock1a_bn (BatchNormalization) (None, 64, 96, 32)   128         block1a_dwconv[0][0]             \n__________________________________________________________________________________________________\nblock1a_activation (Activation) (None, 64, 96, 32)   0           block1a_bn[0][0]                 \n__________________________________________________________________________________________________\nblock1a_se_squeeze (GlobalAvera (None, 32)           0           block1a_activation[0][0]         \n__________________________________________________________________________________________________\nblock1a_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1a_se_squeeze[0][0]         \n__________________________________________________________________________________________________\nblock1a_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1a_se_reshape[0][0]         \n__________________________________________________________________________________________________\nblock1a_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1a_se_reduce[0][0]          \n__________________________________________________________________________________________________\nblock1a_se_excite (Multiply)    (None, 64, 96, 32)   0           block1a_activation[0][0]         \n                                                                 block1a_se_expand[0][0]          \n__________________________________________________________________________________________________\nblock1a_project_conv (Conv2D)   (None, 64, 96, 16)   512         block1a_se_excite[0][0]          \n__________________________________________________________________________________________________\nblock1a_project_bn (BatchNormal (None, 64, 96, 16)   64          block1a_project_conv[0][0]       \n__________________________________________________________________________________________________\nblock2a_expand_conv (Conv2D)    (None, 64, 96, 96)   1536        block1a_project_bn[0][0]         \n__________________________________________________________________________________________________\nblock2a_expand_bn (BatchNormali (None, 64, 96, 96)   384         block2a_expand_conv[0][0]        \n__________________________________________________________________________________________________\nblock2a_expand_activation (Acti (None, 64, 96, 96)   0           block2a_expand_bn[0][0]          \n__________________________________________________________________________________________________\nblock2a_dwconv (DepthwiseConv2D (None, 32, 48, 96)   864         block2a_expand_activation[0][0]  \n______________________________________________________________________ ...
#    'source': 'model.summary()'},
#   {'cell_type': 'code',
#    'execution_count': 16,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:55:23.110646',
#      'end_time': '2020-06-17T13:55:23.125635',
#      'duration': 0.014989,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:55:23.123449Z',
#      'iopub.execute_input': '2020-06-17T13:55:23.123724Z',
#      'shell.execute_reply': '2020-06-17T13:55:23.125180Z',
#      'iopub.status.idle': '2020-06-17T13:55:23.125574Z'}},
#    'outputs': [],
#    'source': '#preparing metrics\n\nif not exists(\'output\'):\n    mkdir(\'output\')\n    \nif not exists(join(\'output\',model_name)):\n    mkdir(join(\'output\',model_name))\n\nsave_model_path = join(\'output\',model_name,\'model_weights.h5\')\n\nMODEL_CFG = {\n    \'optimizer\': Adam(lr=0.001),\n    \'loss\': \'categorical_crossentropy\',\n    \'metrics\': [\'accuracy\'],\n    \'name\': save_model_path\n}\n\nCL_BEST_MODEL= ModelCheckpoint(MODEL_CFG[\'name\'], \n                                 monitor=\'val_loss\', \n                                 verbose=1, \n                                 save_best_only=True,\n                                 save_weights_only=True,\n                                 mode=\'min\')\n    \nCL_REDUCE_LR = ReduceLROnPlateau(monitor=\'val_loss\',\n                                  factor=0.5,\n                                  verbose=0,\n                                  min_lr = 1e-5,\n                                  patience=10)\n\nCL_EARLY_STOPPING = EarlyStopping(monitor = "val_loss" , verbose = 1 , mode = \'min\' , patience = 50)\n\nCALLBACKS = [CL_BEST_MODEL,CL_REDUCE_LR,CL_EARLY_STOPPING]'},
#   {'cell_type': 'code',
#    'execution_count': 17,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:55:23.136652',
#      'end_time': '2020-06-17T13:55:23.163926',
#      'duration': 0.027274,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:55:23.157027Z',
#      'iopub.execute_input': '2020-06-17T13:55:23.158088Z',
#      'shell.execute_reply': '2020-06-17T13:55:23.163207Z',
#      'iopub.status.idle': '2020-06-17T13:55:23.163845Z'}},
#    'outputs': [],
#    'source': "model.compile(\n            optimizer = MODEL_CFG['optimizer'],\n            loss = MODEL_CFG['loss'],\n            metrics = MODEL_CFG['metrics'],\n        )"},
#   {'cell_type': 'code',
#    'execution_count': 18,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:55:23.176742',
#      'end_time': '2020-06-17T13:55:23.190229',
#      'duration': 0.013487,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:55:23.188530Z',
#      'iopub.execute_input': '2020-06-17T13:55:23.188800Z',
#      'shell.execute_reply': '2020-06-17T13:55:23.189919Z',
#      'iopub.status.idle': '2020-06-17T13:55:23.190187Z'}},
#    'outputs': [],
#    'source': 'def train_model(model,\n                train_generator,\n                val_generator = None,\n                epochs = 10,\n                steps = 22,\n                class_weights = None\n               ):\n\n    history = model.fit_generator(\n        generator = train_generator,\n        epochs=epochs,\n        verbose=1,\n        validation_data = val_generator,\n        callbacks=CALLBACKS,\n        class_weight = class_weights\n    )\n    \n    return history'},
#   {'cell_type': 'code',
#    'execution_count': 19,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:55:23.202089',
#      'end_time': '2020-06-17T13:55:23.386806',
#      'duration': 0.184717,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:55:23.214399Z',
#      'iopub.execute_input': '2020-06-17T13:55:23.214696Z',
#      'shell.execute_reply': '2020-06-17T13:55:23.386231Z',
#      'iopub.status.idle': '2020-06-17T13:55:23.386725Z'}},
#    'outputs': [],
#    'source': "from DataGenerator import DataGenerator\n\ngen_train = DataGenerator(x_train_pathology,y_train_pathology,batch_size,augment = config['do_augmentation'])\n\ngen_val = DataGenerator(x_val_pathology,y_val_pathology,batch_size,shuffle=False,augment=False)"},
#   {'cell_type': 'code',
#    'execution_count': 20,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:55:23.402732',
#      'end_time': '2020-06-17T13:59:44.642370',
#      'duration': 261.239638,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:55:23.414687Z',
#      'iopub.execute_input': '2020-06-17T13:55:23.414950Z',
#      'iopub.status.idle': '2020-06-17T13:59:44.642021Z',
#      'shell.execute_reply': '2020-06-17T13:59:44.642300Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'WARNING:tensorflow:From <ipython-input-18-0c5ca30b6301>:15: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.\nInstructions for updating:\nPlease use Model.fit, which supports generators.\n'},
#     {'output_type': 'stream', 'name': 'stdout', 'text': 'Epoch 1/3\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r1/8 [==>...........................] - ETA: 0s - loss: 1.1363 - accuracy: 0.3516'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r2/8 [======>.......................] - ETA: 29s - loss: 1.0691 - accuracy: 0.4258'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r3/8 [==========>...................] - ETA: 32s - loss: 1.0092 - accuracy: 0.4896'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r4/8 [==============>...............] - ETA: 29s - loss: 0.9489 - accuracy: 0.5215'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r5/8 [=================>............] - ETA: 23s - loss: 0.8889 - accuracy: 0.5609'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r6/8 [=====================>........] - ETA: 16s - loss: 0.8277 - accuracy: 0.6003'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r7/8 [=========================>....] - ETA: 8s - loss: 0.7622 - accuracy: 0.6384 '},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r8/8 [==============================] - ETA: 0s - loss: 0.7159 - accuracy: 0.6650'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\nEpoch 00001: val_loss improved from inf to 1.20437, saving model to output/datagen-test/model_weights.h5\n\r8/8 [==============================] - 75s 9s/step - loss: 0.7159 - accuracy: 0.6650 - val_loss: 1.2044 - val_accuracy: 0.4805 - lr: 0.0010\n'},
#     {'output_type': 'stream', 'name': 'stdout', 'text': 'Epoch 2/3\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r1/8 [==>...........................] - ETA: 0s - loss: 0.2181 - accuracy: 0.9219'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r2/8 [======>.......................] - ETA: 29s - loss: 0.2257 - accuracy: 0.9141'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r3/8 [==========>...................] - ETA: 32s - loss: 0.2140 - accuracy: 0.9167'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r4/8 [==============>...............] - ETA: 29s - loss: 0.1937 - accuracy: 0.9258'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r5/8 [=================>............] - ETA: 23s - loss: 0.2014 - accuracy: 0.9187'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r6/8 [=====================>........] - ETA: 16s - loss: 0.1911 - accuracy: 0.9232'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r7/8 [=========================>....] - ETA: 8s - loss: 0.1938 - accuracy: 0.9252 '},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r8/8 [==============================] - ETA: 0s - loss: 0.1917 - accuracy: 0.9258'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\nEpoch 00002: val_loss did not improve from 1.20437\n\r8/8 [==============================] - 74s 9s/step - loss: 0.1917 - accuracy: 0.9258 - val_loss: 1.5601 - val_accuracy: 0.6250 - lr: 0.0010\n'},
#     {'output_type': 'stream', 'name': 'stdout', 'text': 'Epoch 3/3\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r1/8 [==>...........................] - ETA: 0s - loss: 0.0954 - accuracy: 0.9688'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r2/8 [======>.......................] - ETA: 29s - loss: 0.1183 - accuracy: 0.9531'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r3/8 [==========>...................] - ETA: 32s - loss: 0.0998 - accuracy: 0.9635'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r4/8 [==============>...............] - ETA: 29s - loss: 0.1097 - accuracy: 0.9609'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r5/8 [=================>............] - ETA: 23s - loss: 0.1229 - accuracy: 0.9578'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r6/8 [=====================>........] - ETA: 16s - loss: 0.1162 - accuracy: 0.9596'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r7/8 [=========================>....] - ETA: 8s - loss: 0.1093 - accuracy: 0.9621 '},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r8/8 [==============================] - ETA: 0s - loss: 0.1164 - accuracy: 0.9600'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\nEpoch 00003: val_loss improved from 1.20437 to 1.02250, saving model to output/datagen-test/model_weights.h5\n\r8/8 [==============================] - 75s 9s/step - loss: 0.1164 - accuracy: 0.9600 - val_loss: 1.0225 - val_accuracy: 0.7305 - lr: 0.0010\n'}],
#    'source': 'history = None\nif need_training:\n    history = train_model(model,gen_train,gen_val,epochs=epochs)'},
#   {'cell_type': 'code',
#    'execution_count': 21,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:59:44.684238',
#      'end_time': '2020-06-17T13:59:44.706890',
#      'duration': 0.022652,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:59:44.704865Z',
#      'iopub.execute_input': '2020-06-17T13:59:44.705129Z',
#      'iopub.status.idle': '2020-06-17T13:59:44.706582Z',
#      'shell.execute_reply': '2020-06-17T13:59:44.706836Z'}},
#    'outputs': [],
#    'source': "import pickle\n\nif history is not None:\n    history_path = join('output',model_name,'history')\n    with open(history_path, 'wb') as f:\n        pickle.dump(history.history, f)"},
#   {'cell_type': 'code',
#    'execution_count': 22,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:59:44.721309',
#      'end_time': '2020-06-17T13:59:44.773655',
#      'duration': 0.052346,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:59:44.742053Z',
#      'iopub.execute_input': '2020-06-17T13:59:44.752490Z',
#      'shell.execute_reply': '2020-06-17T13:59:44.773354Z',
#      'iopub.status.idle': '2020-06-17T13:59:44.773615Z'}},
#    'outputs': [],
#    'source': 'model_json = model.to_json()\nwith open(join(\'output\',model_name,\'model.json\'), "w") as json_file:\n    json_file.write(model_json)'},
#   {'cell_type': 'code',
#    'execution_count': 23,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:59:44.788824',
#      'end_time': '2020-06-17T13:59:44.960883',
#      'duration': 0.172059,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:59:44.811047Z',
#      'iopub.execute_input': '2020-06-17T13:59:44.811311Z',
#      'shell.execute_reply': '2020-06-17T13:59:44.960376Z',
#      'iopub.status.idle': '2020-06-17T13:59:44.960803Z'}},
#    'outputs': [],
#    'source': "model.save_weights(join('output',model_name,'model_weights.h5'))"}],
#  'metadata': {'celltoolbar': 'Tags',
#   'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.7.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'parameters': {'train_pathology_path': 'data/train_pathology.csv',
#     'test_pathology_path': 'data/test_pathology.csv',
#     'train_plants_path': 'data/train_plants.csv',
#     'test_plants_path': 'data/test_plants.csv'},
#    'environment_variables': {},
#    'version': '2.1.0',
#    'input_path': 'train_model.ipynb',
#    'output_path': 'output_notebooks/train_model.ipynb',
#    'start_time': '2020-06-17T13:55:07.879580',
#    'end_time': '2020-06-17T13:59:45.087749',
#    'duration': 277.208169,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 4}

# %%
#запускаем репорт

model_name = config['model_name']

pm.execute_notebook(
    input_path = 'report.ipynb',
    output_path = craft_output_notebook_name('report.ipynb'),
    parameters = dict(
        model_name = config['model_name'],
        model_path = join('output',model_name,'model.json'),
        weights_path = join('output',model_name,'model_weights.h5'),
        history_path = join('output',model_name,'history'),
        csv_path = 'data/test_pathology.csv'
    ),
    nest_asyncio=True
)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Executing', max=10.0, style=ProgressStyle(description_wid…
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:59:49.404159',
#      'end_time': '2020-06-17T13:59:49.411030',
#      'duration': 0.006871,
#      'status': 'completed'}},
#    'source': 'txt file, в котором в первой строке написано название модели\n(его можно взять из конфиг файла)\nво второй строке написан acc\nв третьей строке написан loss\nво четвертой строке написан val acc\nв пятой строке написан val loss\nсохранить png картинку с графиком (сделать все на один график и лосс и вал лосс и акк и вал акк)\nнемесил в пакетике'},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:59:49.417555',
#      'end_time': '2020-06-17T13:59:50.729032',
#      'duration': 1.311477,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:59:49.425502Z',
#      'iopub.execute_input': '2020-06-17T13:59:49.425771Z',
#      'shell.execute_reply': '2020-06-17T13:59:50.728448Z',
#      'iopub.status.idle': '2020-06-17T13:59:50.728933Z'}},
#    'outputs': [],
#    'source': 'import tensorflow as tf\nimport pickle\nimport matplotlib.pyplot as plt\nimport numpy as np\nfrom tensorflow.keras.optimizers import Adam\nfrom tensorflow.keras.models import Model\nfrom os.path import join\nimport efficientnet.tfkeras as efn\nimport pandas as pd'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:59:50.736499',
#      'end_time': '2020-06-17T13:59:51.540379',
#      'duration': 0.80388,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:59:51.538179Z',
#      'iopub.execute_input': '2020-06-17T13:59:51.538712Z',
#      'iopub.status.idle': '2020-06-17T13:59:51.539758Z',
#      'shell.execute_reply': '2020-06-17T13:59:51.540259Z'}},
#    'outputs': [],
#    'source': "import tensorflow as tf\ngpus = tf.config.experimental.list_physical_devices('GPU')\ntf.config.experimental.set_memory_growth(gpus[0], True)"},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:59:51.548291',
#      'end_time': '2020-06-17T13:59:51.557234',
#      'duration': 0.008943,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:59:51.555184Z',
#      'iopub.execute_input': '2020-06-17T13:59:51.555446Z',
#      'shell.execute_reply': '2020-06-17T13:59:51.556777Z',
#      'iopub.status.idle': '2020-06-17T13:59:51.557172Z'}},
#    'outputs': [],
#    'source': "model_name = 'PSU_model'\nmodel_path = join('output',model_name,'model.json')\nweights_path = join('output',model_name,'model_weights.h5')\nhistory_path = join('output',model_name,'history')\ncsv_path = 'data/test_pathology.csv'"},
#   {'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:59:51.562509',
#      'end_time': '2020-06-17T13:59:51.571926',
#      'duration': 0.009417,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:59:51.570112Z',
#      'iopub.execute_input': '2020-06-17T13:59:51.570412Z',
#      'shell.execute_reply': '2020-06-17T13:59:51.571626Z',
#      'iopub.status.idle': '2020-06-17T13:59:51.571882Z'}},
#    'execution_count': 4,
#    'source': '# Parameters\nmodel_name = "datagen-test"\nmodel_path = "output/datagen-test/model.json"\nweights_path = "output/datagen-test/model_weights.h5"\nhistory_path = "output/datagen-test/history"\ncsv_path = "data/test_pathology.csv"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:59:51.575465',
#      'end_time': '2020-06-17T13:59:51.585101',
#      'duration': 0.009636,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:59:51.583313Z',
#      'iopub.execute_input': '2020-06-17T13:59:51.583614Z',
#      'iopub.status.idle': '2020-06-17T13:59:51.584840Z',
#      'shell.execute_reply': '2020-06-17T13:59:51.585050Z'}},
#    'outputs': [],
#    'source': 'def prepare_model(model_path,weights_path,history):\n    with open(model_path,\'r\') as f:\n        json_config = f.read()\n        model = tf.keras.models.model_from_json(json_config)\n        model.load_weights(weights_path)\n        model.compile(loss=\'categorical_crossentropy\',\n                      optimizer=Adam(history["lr"][len(history["lr"])-1]),\n                      metrics=[\'accuracy\'])\n        return model'},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:59:51.589269',
#      'end_time': '2020-06-17T13:59:51.598724',
#      'duration': 0.009455,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:59:51.596913Z',
#      'iopub.execute_input': '2020-06-17T13:59:51.597166Z',
#      'shell.execute_reply': '2020-06-17T13:59:51.598423Z',
#      'iopub.status.idle': '2020-06-17T13:59:51.598682Z'}},
#    'outputs': [],
#    'source': "def load_history(history_path):\n    with open(history_path,'rb') as f:\n        return pickle.load(f)"},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:59:51.602395',
#      'end_time': '2020-06-17T13:59:51.610512',
#      'duration': 0.008117,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:59:51.608759Z',
#      'iopub.execute_input': '2020-06-17T13:59:51.609017Z',
#      'shell.execute_reply': '2020-06-17T13:59:51.610210Z',
#      'iopub.status.idle': '2020-06-17T13:59:51.610472Z'}},
#    'outputs': [],
#    'source': "def get_test_data(path):\n    df = pd.read_csv(path)\n    paths = df.pop('path')\n    paths = [str(elem) for elem in paths]\n    y = df.to_numpy().astype('float32')\n    return np.array(paths),y"},
#   {'cell_type': 'code',
#    'execution_count': 8,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:59:51.614320',
#      'end_time': '2020-06-17T13:59:51.624897',
#      'duration': 0.010577,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:59:51.622900Z',
#      'iopub.execute_input': '2020-06-17T13:59:51.623299Z',
#      'shell.execute_reply': '2020-06-17T13:59:51.624447Z',
#      'iopub.status.idle': '2020-06-17T13:59:51.624838Z'}},
#    'outputs': [],
#    'source': "def get_prediction(history):\n    \n    model = prepare_model(model_path,weights_path,history)\n    \n    pics_names,lbls = get_test_data(csv_path)\n    pics = []\n    \n    for pic in pics_names:\n        pic_ = np.load(pic).astype('float32')/255\n        pics.append(pic_)\n    \n    pics = np.asarray(pics)\n    \n    result = model.evaluate(pics,lbls)\n    return result[0], result[1]"},
#   {'cell_type': 'code',
#    'execution_count': 9,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-06-17T13:59:51.630696',
#      'end_time': '2020-06-17T14:00:03.059149',
#      'duration': 11.428453,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-06-17T13:59:51.644735Z',
#      'iopub.execute_input': '2020-06-17T13:59:51.645247Z',
#      'shell.execute_reply': '2020-06-17T14:00:03.058792Z',
#      'iopub.status.idle': '2020-06-17T14:00:03.059092Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r 1/11 [=>............................] - ETA: 0s - loss: 0.8347 - accuracy: 0.6562'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r 2/11 [====>.........................] - ETA: 3s - loss: 0.8552 - accuracy: 0.7188'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r 3/11 [=======>......................] - ETA: 3s - loss: 0.9560 - accuracy: 0.7188'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r 4/11 [=========>....................] - ETA: 3s - loss: 0.9405 - accuracy: 0.7031'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r 5/11 [============>.................] - ETA: 3s - loss: 1.0082 - accuracy: 0.7000'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r 6/11 [===============>..............] - ETA: 2s - loss: 1.0521 - accuracy: 0.6823'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r 7/11 [==================>...........] - ETA: 2s - loss: 1.0063 - accuracy: 0.7009'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r 8/11 [====================>.........] - ETA: 1s - loss: 0.9434 - accuracy: 0.7227'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r 9/11 [=======================>......] - ETA: 1s - loss: 1.0018 - accuracy: 0.7153'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r10/11 [==========================>...] - ETA: 0s - loss: 0.9791 - accuracy: 0.7219'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r11/11 [==============================] - ETA: 0s - loss: 0.9909 - accuracy: 0.7197'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r11/11 [==============================] - 7s 612ms/step - loss: 0.9909 - accuracy: 0.7197\n'},
#     {'output_type': 'display_data',
#      'metadata': {'needs_background': 'light'},
#      'data': {'text/plain': '<Figure size 432x288 with 1 Axes>',
#       'image/png': '...\n'}}],
#    'source': 'with open(join(\'output\',model_name,\'report.txt\'),\'w\') as f:\n        #с истории выколупываем \n        f.write(\'model name: \'+ model_name+\'\\n\')\n        history = load_history(history_path)\n        #\n        test_loss, test_acc = get_prediction(history)\n        #test_loss,test_acc = 0.5,0.3\n        #сохраняется картинОЧКА\n        figure, _ = plt.subplots()\n        plt.rcParams["figure.figsize"] = (8,8)\n        plt.plot(history["accuracy"])\n        plt.plot(history[\'val_accuracy\'])\n        plt.plot(history[\'loss\'])\n        plt.plot(history[\'val_loss\'])\n        plt.title("Accuracy and Loss")\n        plt.ylabel("Value")\n        plt.xlabel("Epoch")\n        plt.legend(["Accuracy","Val. Accuracy","Loss","Validation Loss"])\n        figure.savefig(join(\'output\',model_name,\'plots.png\'))\n        #\n        f.write(\'train accuracy: \'+str(history["accuracy"][len(history["accuracy"])-1])+\'\\n\')\n        f.write(\'validation accuracy: \'+str(history["val_accuracy"][len(history["val_accuracy"])-1])+\'\\n\')\n        f.write(\'test accuracy: \'+str(test_acc)+\'\\n\')\n        f.write(\'train loss: \'+str(history["loss"][len(history["loss"])-1])+\'\\n\')\n        f.write(\'validation loss: \'+str(history["val_loss"][len(history["val_loss"])-1])+\'\\n\')\n        f.write(\'test loss: \'+str(test_loss)+\'\\n\')'}],
#  'metadata': {'celltoolbar': 'Tags',
#   'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.7.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'parameters': {'model_name': 'datagen-test',
#     'model_path': 'output/datagen-test/model.json',
#     'weights_path': 'output/datagen-test/model_weights.h5',
#     'history_path': 'output/datagen-test/history',
#     'csv_path': 'data/test_pathology.csv'},
#    'environment_variables': {},
#    'version': '2.1.0',
#    'input_path': 'report.ipynb',
#    'output_path': 'output_notebooks/report.ipynb',
#    'start_time': '2020-06-17T13:59:48.901932',
#    'end_time': '2020-06-17T14:00:03.172417',
#    'duration': 14.270485,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 4}

# %%
#сохраняем конфиг
import shutil
shutil.copy('config.json',join('output',model_name,'config.json'))
# Out:
# 'output/datagen-test/config.json'

# %%
#запускаем блокнот с визуализацией

viz_data = 'data/test_pathology.csv'

pm.execute_notebook(
    input_path = 'visualization.ipynb',
    output_path = join('output',model_name,'visualization.ipynb'),
    parameters = dict(
        model_name = config['model_name'],
        model_path = join('output',model_name,'model.json'),
        weights_path = join('output',model_name,'model_weights.h5'),
        csv_path = viz_data,
        augment_on_predict = False
    ),
    nest_asyncio=True
)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Executing', max=20.0, style=ProgressStyle(description_wid…
